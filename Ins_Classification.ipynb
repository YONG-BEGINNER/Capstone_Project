# %% [markdown]
# ## Import Library

# %%
import os
import cv2
import json
import math
import torch
import torchvision
import numpy as np
import torch.nn as nn
from tqdm import tqdm
from PIL import ImageFile
import PIL.Image as Image
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torchsummary import summary
from collections import Counter
import torchvision.transforms as transforms
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %% [markdown]
# ## Configurations Setup

# %%
image_size = 224
batch_size = 32
num_workers = 8
learning_rate = 1e-4
num_epoch = 50
train_ratio = 0.7

# %% [markdown]
# ## Load Dataset

# %%
data = torchvision.datasets.ImageFolder(root='./archive (1)')

# %% [markdown]
# ### Splitting the data into train and test set

# %%
train_size = int(train_ratio * len(data))
test_size = len(data) - train_size

train_dataset, test_dataset = torch.utils.data.random_split(data, [train_size, test_size])

# %%
train_transform = transforms.Compose([  transforms.Resize((image_size, image_size)),
                                        transforms.RandomAffine(degrees=(-90, 90),scale=(0.85, 0.95)),
                                        transforms.RandomHorizontalFlip(),
                                        transforms.RandomVerticalFlip(),
                                        transforms.ToTensor()])

test_transform = transforms.Compose([transforms.Resize((image_size, image_size)),
                                                     transforms.ToTensor()])

# %%
train_dataset = torch.utils.data.Subset(torchvision.datasets.ImageFolder(root='./archive (1)', transform=train_transform), train_dataset.indices)
test_dataset = torch.utils.data.Subset(torchvision.datasets.ImageFolder(root='./archive (1)', transform=test_transform), test_dataset.indices)

# %%
print(f"Total of Data: {len(data)}")
print(f"Training set size: {len(train_dataset)}")
print(f"Testing set size: {len(test_dataset)}")
# Out:
# Total of Data: 8605
# Training set size: 6023
# Testing set size: 2582

# %%
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size,
                                          shuffle=True, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size,
                                          shuffle=True, num_workers=num_workers)

# %% [markdown]
# ### Count the data that consist in each classes

# %%
# Function to count samples per class
def count_samples_per_class(dataset):
    labels = [label for _, label in dataset]
    label_count = Counter(labels)
    return label_count

# %%
label_count = count_samples_per_class(train_dataset)
num_classes = len(label_count)
print("Total number of data: ", len(train_dataset))
print("Number of classes:", num_classes)
print("Number of data samples per class:", label_count)
# Out:
# d:\Program_File\anaconda3\envs\pytorch_1\Lib\site-packages\PIL\Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Total number of data:  6023
# Number of classes: 11
# Number of data samples per class: Counter({1: 754, 2: 667, 5: 615, 6: 592, 10: 569, 3: 565, 0: 520, 4: 473, 7: 470, 9: 432, 8: 366})

# %%
label_count = count_samples_per_class(test_dataset)
num_classes = len(label_count)
print("Total number of data: ", len(test_dataset))
print("Number of classes:", num_classes)
print("Number of data samples per class:", label_count)
# Out:
# Total number of data:  2582
# Number of classes: 11
# Number of data samples per class: Counter({1: 334, 5: 265, 2: 265, 6: 247, 10: 247, 3: 230, 9: 219, 0: 214, 4: 204, 7: 184, 8: 173})
# d:\Program_File\anaconda3\envs\pytorch_1\Lib\site-packages\PIL\TiffImagePlugin.py:900: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))

# %% [markdown]
# ### Show sample Image with Label

# %%
cat_to_name = {'1':'Ant', '2':'Bee', '3': 'Bettle', '4': 'Butterfly', '5': 'Dragonfly', '6':'Fly', '7':'Grasshoper', '8':'Ladybug', '9':'Mosquito', '10':'Spider', '11':'Wasp'}
def imshow(img_tensor, ax, label):
    """ Utility function to display an image tensor with a caption. """
    if img_tensor.shape[0] == 3:  # Check if it's an RGB image
        ax.imshow(img_tensor.permute(1, 2, 0))  # Reorder dimensions to (height, width, channels)
    else:
        ax.imshow(img_tensor[0], cmap='gray')  # Display the first channel (grayscale)
    ax.axis('off')
    ax.set_title(label, fontsize=10)

def show_images_batch(images_batch, labels):
    """
    Display a batch of images in a grid with labels.
    """

    batch_size = images_batch.shape[0]
    grid_cols = int(np.ceil(np.sqrt(batch_size)))
    grid_rows = int(np.ceil(batch_size / grid_cols))  # Ensure all images fit in the grid

    fig, axes = plt.subplots(grid_rows, grid_cols, figsize=(grid_cols * 2.5, grid_rows * 2.5))
    if grid_rows * grid_cols == 1:  # Special case for single image
        axes = [axes]  # Make it iterable

    # Check if axes is still not iterable
    if not isinstance(axes, np.ndarray):
        axes = np.array([axes])


    for i in range(grid_rows * grid_cols):
        ax = axes.flatten()[i]
        if i < batch_size:
            # imshow(images_batch[i], ax, labels[i].item())
            imshow(images_batch[i], ax, cat_to_name[str(labels[i].item() + 1)])
        else:
            ax.axis('off')

    plt.tight_layout()
    plt.show()

# %%
for idx, data in enumerate(train_loader):

  show_images_batch(images_batch=data[0], labels=data[1])
  break

# %% [markdown]
# ## Load Model (Restnet18)

# %%
restnet_model = torchvision.models.resnet18().cuda()

# %%
for n, p in restnet_model.named_parameters():
  print(n)
# Out:
# conv1.weight
# bn1.weight
# bn1.bias
# layer1.0.conv1.weight
# layer1.0.bn1.weight
# layer1.0.bn1.bias
# layer1.0.conv2.weight
# layer1.0.bn2.weight
# layer1.0.bn2.bias
# layer1.1.conv1.weight
# layer1.1.bn1.weight
# layer1.1.bn1.bias
# layer1.1.conv2.weight
# layer1.1.bn2.weight
# layer1.1.bn2.bias
# layer2.0.conv1.weight
# layer2.0.bn1.weight
# layer2.0.bn1.bias
# layer2.0.conv2.weight
# layer2.0.bn2.weight
# layer2.0.bn2.bias
# layer2.0.downsample.0.weight
# layer2.0.downsample.1.weight
# layer2.0.downsample.1.bias
# layer2.1.conv1.weight
# layer2.1.bn1.weight
# layer2.1.bn1.bias
# layer2.1.conv2.weight
# layer2.1.bn2.weight
# layer2.1.bn2.bias
# layer3.0.conv1.weight
# layer3.0.bn1.weight
# layer3.0.bn1.bias
# layer3.0.conv2.weight
# layer3.0.bn2.weight
# layer3.0.bn2.bias
# layer3.0.downsample.0.weight
# layer3.0.downsample.1.weight
# layer3.0.downsample.1.bias
# layer3.1.conv1.weight
# layer3.1.bn1.weight
# layer3.1.bn1.bias
# layer3.1.conv2.weight
# layer3.1.bn2.weight
# layer3.1.bn2.bias
# layer4.0.conv1.weight
# layer4.0.bn1.weight
# layer4.0.bn1.bias
# layer4.0.conv2.weight
# layer4.0.bn2.weight
# layer4.0.bn2.bias
# layer4.0.downsample.0.weight
# layer4.0.downsample.1.weight
# layer4.0.downsample.1.bias
# layer4.1.conv1.weight
# layer4.1.bn1.weight
# layer4.1.bn1.bias
# layer4.1.conv2.weight
# layer4.1.bn2.weight
# layer4.1.bn2.bias
# fc.weight
# fc.bias

# %%
for p in restnet_model.parameters():
  p.requires_grad = False

# %%
summary(restnet_model, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#        BasicBlock-11           [-1, 64, 56, 56]               0
#            Conv2d-12           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-13           [-1, 64, 56, 56]             128
#              ReLU-14           [-1, 64, 56, 56]               0
#            Conv2d-15           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-16           [-1, 64, 56, 56]             128
#              ReLU-17           [-1, 64, 56, 56]               0
#        BasicBlock-18           [-1, 64, 56, 56]               0
#            Conv2d-19          [-1, 128, 28, 28]          73,728
#       BatchNorm2d-20          [-1, 128, 28, 28]             256
#              ReLU-21          [-1, 128, 28, 28]               0
#            Conv2d-22          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-23          [-1, 128, 28, 28]             256
#            Conv2d-24          [-1, 128, 28, 28]           8,192
#       BatchNorm2d-25          [-1, 128, 28, 28]             256
#              ReLU-26          [-1, 128, 28, 28]               0
#        BasicBlock-27          [-1, 128, 28, 28]               0
#            Conv2d-28          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-29          [-1, 128, 28, 28]             256
#              ReLU-30          [-1, 128, 28, 28]               0
#            Conv2d-31          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-32          [-1, 128, 28, 28]             256
#              ReLU-33          [-1, 128, 28, 28]               0
#        BasicBlock-34          [-1, 128, 28, 28]               0
#            Conv2d-35          [-1, 256, 14, 14]         294,912
#       BatchNorm2d-36          [-1, 256, 14, 14]             512
#              ReLU-37          [-1, 256, 14, 14]               0
#            Conv2d-38          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-39          [-1, 256, 14, 14]             512
#            Conv2d-40          [-1, 256, 14, 14]          32,768
#       BatchNorm2d-41          [-1, 256, 14, 14]             512
#              ReLU-42          [-1, 256, 14, 14]               0
#        BasicBlock-43          [-1, 256, 14, 14]               0
#            Conv2d-44          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-45          [-1, 256, 14, 14]             512
#              ReLU-46          [-1, 256, 14, 14]               0
#            Conv2d-47          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-48          [-1, 256, 14, 14]             512
#              ReLU-49          [-1, 256, 14, 14]               0
#        BasicBlock-50          [-1, 256, 14, 14]               0
#            Conv2d-51            [-1, 512, 7, 7]       1,179,648
#       BatchNorm2d-52            [-1, 512, 7, 7]           1,024
#              ReLU-53            [-1, 512, 7, 7]               0
#            Conv2d-54            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-55            [-1, 512, 7, 7]           1,024
#            Conv2d-56            [-1, 512, 7, 7]         131,072
#       BatchNorm2d-57            [-1, 512, 7, 7]           1,024
#              ReLU-58            [-1, 512, 7, 7]               0
#        BasicBlock-59            [-1, 512, 7, 7]               0
#            Conv2d-60            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-61            [-1, 512, 7, 7]           1,024
#              ReLU-62            [-1, 512, 7, 7]               0
#            Conv2d-63            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-64            [-1, 512, 7, 7]           1,024
#              ReLU-65            [-1, 512, 7, 7]               0
#        BasicBlock-66            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                 [-1, 1000]         513,000
# ================================================================
# Total params: 11,689,512
# Trainable params: 0
# Non-trainable params: 11,689,512
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 62.79
# Params size (MB): 44.59
# Estimated Total Size (MB): 107.96
# ----------------------------------------------------------------

# %%
for p in restnet_model.named_parameters():
  # print(p[0])
  if any(layer in p[0] for layer in ['layer1', 'layer2', 'layer4']):
    p[1].requires_grad = True

# %%
summary(restnet_model, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#        BasicBlock-11           [-1, 64, 56, 56]               0
#            Conv2d-12           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-13           [-1, 64, 56, 56]             128
#              ReLU-14           [-1, 64, 56, 56]               0
#            Conv2d-15           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-16           [-1, 64, 56, 56]             128
#              ReLU-17           [-1, 64, 56, 56]               0
#        BasicBlock-18           [-1, 64, 56, 56]               0
#            Conv2d-19          [-1, 128, 28, 28]          73,728
#       BatchNorm2d-20          [-1, 128, 28, 28]             256
#              ReLU-21          [-1, 128, 28, 28]               0
#            Conv2d-22          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-23          [-1, 128, 28, 28]             256
#            Conv2d-24          [-1, 128, 28, 28]           8,192
#       BatchNorm2d-25          [-1, 128, 28, 28]             256
#              ReLU-26          [-1, 128, 28, 28]               0
#        BasicBlock-27          [-1, 128, 28, 28]               0
#            Conv2d-28          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-29          [-1, 128, 28, 28]             256
#              ReLU-30          [-1, 128, 28, 28]               0
#            Conv2d-31          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-32          [-1, 128, 28, 28]             256
#              ReLU-33          [-1, 128, 28, 28]               0
#        BasicBlock-34          [-1, 128, 28, 28]               0
#            Conv2d-35          [-1, 256, 14, 14]         294,912
#       BatchNorm2d-36          [-1, 256, 14, 14]             512
#              ReLU-37          [-1, 256, 14, 14]               0
#            Conv2d-38          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-39          [-1, 256, 14, 14]             512
#            Conv2d-40          [-1, 256, 14, 14]          32,768
#       BatchNorm2d-41          [-1, 256, 14, 14]             512
#              ReLU-42          [-1, 256, 14, 14]               0
#        BasicBlock-43          [-1, 256, 14, 14]               0
#            Conv2d-44          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-45          [-1, 256, 14, 14]             512
#              ReLU-46          [-1, 256, 14, 14]               0
#            Conv2d-47          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-48          [-1, 256, 14, 14]             512
#              ReLU-49          [-1, 256, 14, 14]               0
#        BasicBlock-50          [-1, 256, 14, 14]               0
#            Conv2d-51            [-1, 512, 7, 7]       1,179,648
#       BatchNorm2d-52            [-1, 512, 7, 7]           1,024
#              ReLU-53            [-1, 512, 7, 7]               0
#            Conv2d-54            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-55            [-1, 512, 7, 7]           1,024
#            Conv2d-56            [-1, 512, 7, 7]         131,072
#       BatchNorm2d-57            [-1, 512, 7, 7]           1,024
#              ReLU-58            [-1, 512, 7, 7]               0
#        BasicBlock-59            [-1, 512, 7, 7]               0
#            Conv2d-60            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-61            [-1, 512, 7, 7]           1,024
#              ReLU-62            [-1, 512, 7, 7]               0
#            Conv2d-63            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-64            [-1, 512, 7, 7]           1,024
#              ReLU-65            [-1, 512, 7, 7]               0
#        BasicBlock-66            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                 [-1, 1000]         513,000
# ================================================================
# Total params: 11,689,512
# Trainable params: 9,067,264
# Non-trainable params: 2,622,248
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 62.79
# Params size (MB): 44.59
# Estimated Total Size (MB): 107.96
# ----------------------------------------------------------------

# %% [markdown]
# Adjust Model Layer to fit the number of classes

# %%
restnet_model.fc = nn.Linear(512, 11)

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.AdamW(restnet_model.parameters(), lr=learning_rate)

# %%
restnet_model = restnet_model.cuda()

# %%
train_dataset_size = len(train_dataset)

# Calculate the number of iterations per epoch
iterations_per_epoch_train = math.ceil(train_dataset_size / batch_size)

test_dataset_size = len(test_dataset)

# Calculate the number of iterations per epoch
iterations_per_epoch_test = math.ceil(test_dataset_size / batch_size)

print(f"Iterations per epoch(Train): {iterations_per_epoch_train}")
print(f"Iterations per epoch(Test): {iterations_per_epoch_test}")
# Out:
# Iterations per epoch(Train): 189
# Iterations per epoch(Test): 81

# %%
train_losses = []
test_accuracies = []

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device: {device}")
restnet_model.to(device)

for epoch in range(num_epoch):
    restnet_model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0
    
    #Training
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = restnet_model(images)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct_train / total_train
    train_losses.append(train_loss)
    print(f'Epoch [{epoch+1}/{num_epoch}], Loss: {train_loss:.4f}')
    print(f'Training Accuracy: {train_accuracy:.2f}%')

    # Evaluate the resnet_model
    restnet_model.eval()
    correct = 0
    total = 0
    all_labels = []
    all_predictions = []
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = restnet_model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
            #Store the labels and predictions to display confusion matrix
            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    accuracy = 100 * correct / total
    test_accuracies.append(accuracy)
    print(f'Test Accuracy: {accuracy:.2f}%')
# Out:
# Device: cuda
# Epoch [1/50], Loss: 1.7852
# Training Accuracy: 38.45%
# Test Accuracy: 50.27%
# Epoch [2/50], Loss: 1.3763
# Training Accuracy: 53.31%
# Test Accuracy: 55.23%
# Epoch [3/50], Loss: 1.1876
# Training Accuracy: 60.02%
# Test Accuracy: 65.80%
# Epoch [4/50], Loss: 1.0577
# Training Accuracy: 63.94%
# Test Accuracy: 64.25%
# Epoch [5/50], Loss: 0.9706
# Training Accuracy: 67.31%
# Test Accuracy: 69.33%
# Epoch [6/50], Loss: 0.9028
# Training Accuracy: 69.27%
# Test Accuracy: 68.20%
# Epoch [7/50], Loss: 0.8387
# Training Accuracy: 71.16%
# Test Accuracy: 72.15%
# Epoch [8/50], Loss: 0.7924
# Training Accuracy: 73.17%
# Test Accuracy: 71.49%
# Epoch [9/50], Loss: 0.7643
# Training Accuracy: 73.70%
# Test Accuracy: 68.47%
# Epoch [10/50], Loss: 0.7041
# Training Accuracy: 75.91%
# Test Accuracy: 73.59%
# Epoch [11/50], Loss: 0.6914
# Training Accuracy: 76.81%
# Test Accuracy: 77.58%
# Epoch [12/50], Loss: 0.6578
# Training Accuracy: 77.42%
# Test Accuracy: 74.48%
# Epoch [13/50], Loss: 0.6445
# Training Accuracy: 77.82%
# Test Accuracy: 76.92%
# Epoch [14/50], Loss: 0.6054
# Training Accuracy: 79.25%
# Test Accuracy: 77.54%
# Epoch [15/50], Loss: 0.5946
# Training Accuracy: 80.19%
# Test Accuracy: 69.83%
# Epoch [16/50], Loss: 0.5765
# Training Accuracy: 80.39%
# Test Accuracy: 76.92%
# Epoch [17/50], Loss: 0.5351
# Training Accuracy: 81.75%
# Test Accuracy: 78.04%
# Epoch [18/50], Loss: 0.5311
# Training Accuracy: 81.55%
# Test Accuracy: 74.71%
# Epoch [19/50], Loss: 0.5087
# Training Accuracy: 82.60%
# Test Accuracy: 77.38%
# Epoch [20/50], Loss: 0.5028
# Training Accuracy: 82.85%
# Test Accuracy: 80.60%
# Epoch [21/50], Loss: 0.4744
# Training Accuracy: 84.03%
# Test Accuracy: 81.41%
# Epoch [22/50], Loss: 0.4629
# Training Accuracy: 84.18%
# Test Accuracy: 80.75%
# Epoch [23/50], Loss: 0.4512
# Training Accuracy: 84.59%
# Test Accuracy: 82.26%
# Epoch [24/50], Loss: 0.4200
# Training Accuracy: 85.85%
# Test Accuracy: 82.61%
# Epoch [25/50], Loss: 0.4239
# Training Accuracy: 85.14%
# Test Accuracy: 79.86%
# Epoch [26/50], Loss: 0.4218
# Training Accuracy: 86.02%
# Test Accuracy: 83.00%
# Epoch [27/50], Loss: 0.3981
# Training Accuracy: 86.49%
# Test Accuracy: 81.80%
# Epoch [28/50], Loss: 0.3912
# Training Accuracy: 86.34%
# Test Accuracy: 84.00%
# Epoch [29/50], Loss: 0.3647
# Training Accuracy: 87.65%
# Test Accuracy: 83.19%
# Epoch [30/50], Loss: 0.3689
# Training Accuracy: 87.53%
# Test Accuracy: 81.53%
# Epoch [31/50], Loss: 0.3433
# Training Accuracy: 88.26%
# Test Accuracy: 82.53%
# Epoch [32/50], Loss: 0.3458
# Training Accuracy: 88.13%
# Test Accuracy: 84.04%
# Epoch [33/50], Loss: 0.3528
# Training Accuracy: 88.00%
# Test Accuracy: 84.04%
# Epoch [34/50], Loss: 0.3333
# Training Accuracy: 89.06%
# Test Accuracy: 85.13%
# Epoch [35/50], Loss: 0.3152
# Training Accuracy: 89.21%
# Test Accuracy: 84.66%
# Epoch [36/50], Loss: 0.3069
# Training Accuracy: 89.71%
# Test Accuracy: 84.74%
# Epoch [37/50], Loss: 0.2955
# Training Accuracy: 90.40%
# Test Accuracy: 84.08%
# Epoch [38/50], Loss: 0.3182
# Training Accuracy: 89.17%
# Test Accuracy: 83.00%
# Epoch [39/50], Loss: 0.2969
# Training Accuracy: 89.59%
# Test Accuracy: 83.54%
# Epoch [40/50], Loss: 0.2822
# Training Accuracy: 90.47%
# Test Accuracy: 84.12%
# Epoch [41/50], Loss: 0.2684
# Training Accuracy: 90.92%
# Test Accuracy: 83.73%
# Epoch [42/50], Loss: 0.2680
# Training Accuracy: 90.75%
# Test Accuracy: 85.63%
# Epoch [43/50], Loss: 0.2517
# Training Accuracy: 91.57%
# Test Accuracy: 86.10%
# Epoch [44/50], Loss: 0.2426
# Training Accuracy: 91.73%
# Test Accuracy: 86.21%
# Epoch [45/50], Loss: 0.2563
# Training Accuracy: 91.12%
# Test Accuracy: 87.06%
# Epoch [46/50], Loss: 0.2467
# Training Accuracy: 91.65%
# Test Accuracy: 85.40%
# Epoch [47/50], Loss: 0.2402
# Training Accuracy: 92.05%
# Test Accuracy: 84.31%
# Epoch [48/50], Loss: 0.2362
# Training Accuracy: 92.08%
# Test Accuracy: 84.20%
# Epoch [49/50], Loss: 0.2215
# Training Accuracy: 92.35%
# Test Accuracy: 85.82%
# Epoch [50/50], Loss: 0.2366
# Training Accuracy: 92.33%
# Test Accuracy: 86.25%

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(range(1, num_epoch + 1), train_losses, 'b', label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epoch + 1), test_accuracies, 'g', label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.title('Test Accuracy')
plt.legend()

plt.show()

# %%
torch.save(restnet_model.state_dict(), 'restnet_trained.pth')

# %%
print(f"all_labels: {all_labels}")
print(f"all_predictions: {all_predictions}")
# Out:
# all_labels: [np.int64(10), np.int64(2), np.int64(9), np.int64(4), np.int64(5), np.int64(2), np.int64(6), np.int64(9), np.int64(2), np.int64(2), np.int64(7), np.int64(9), np.int64(5), np.int64(7), np.int64(3), np.int64(8), np.int64(6), np.int64(7), np.int64(2), np.int64(10), np.int64(4), np.int64(2), np.int64(2), np.int64(8), np.int64(1), np.int64(3), np.int64(1), np.int64(0), np.int64(5), np.int64(8), np.int64(2), np.int64(10), np.int64(8), np.int64(3), np.int64(2), np.int64(2), np.int64(6), np.int64(3), np.int64(4), np.int64(2), np.int64(6), np.int64(10), np.int64(2), np.int64(8), np.int64(3), np.int64(4), np.int64(9), np.int64(4), np.int64(10), np.int64(9), np.int64(2), np.int64(6), np.int64(1), np.int64(1), np.int64(4), np.int64(6), np.int64(7), np.int64(6), np.int64(0), np.int64(5), np.int64(5), np.int64(0), np.int64(3), np.int64(1), np.int64(2), np.int64(5), np.int64(4), np.int64(0), np.int64(6), np.int64(0), np.int64(4), np.int64(2), np.int64(10), np.int64(3), np.int64(3), np.int64(2), np.int64(2), np.int64(6), np.int64(5), np.int64(10), np.int64(9), np.int64(3), np.int64(9), np.int64(7), np.int64(6), np.int64(1), np.int64(5), np.int64(0), np.int64(0), np.int64(6), np.int64(9), np.int64(3), np.int64(4), np.int64(1), np.int64(8), np.int64(5), np.int64(5), np.int64(0), np.int64(7), np.int64(10), np.int64(5), np.int64(3), np.int64(2), np.int64(10), np.int64(8), np.int64(8), np.int64(7), np.int64(0), np.int64(10), np.int64(5), np.int64(8), np.int64(7), np.int64(9), np.int64(1), np.int64(10), np.int64(1), np.int64(7), np.int64(10), np.int64(3), np.int64(5), np.int64(3), np.int64(2), np.int64(8), np.int64(2), np.int64(5), np.int64(6), np.int64(6), np.int64(10), np.int64(6), np.int64(3), np.int64(0), np.int64(3), np.int64(5), np.int64(1), np.int64(4), np.int64(10), np.int64(3), np.int64(9), np.int64(1), np.int64(8), np.int64(1), np.int64(8), np.int64(7), np.int64(5), np.int64(4), np.int64(2), np.int64(3), np.int64(0), np.int64(10), np.int64(8), np.int64(9), np.int64(3), np.int64(0), np.int64(1), np.int64(10), np.int64(5), np.int64(1), np.int64(0), np.int64(6), np.int64(3), np.int64(1), np.int64(9), np.int64(2), np.int64(3), np.int64(1), np.int64(6), np.int64(4), np.int64(4), np.int64(10), np.int64(10), np.int64(10), np.int64(2), np.int64(7), np.int64(0), np.int64(2), np.int64(3), np.int64(9), np.int64(6), np.int64(2), np.int64(5), np.int64(6), np.int64(4), np.int64(6), np.int64(9), np.int64(10), np.int64(3), np.int64(10), np.int64(0), np.int64(6), np.int64(7), np.int64(2), np.int64(1), np.int64(8), np.int64(0), np.int64(4), np.int64(0), np.int64(6), np.int64(8), np.int64(6), np.int64(1), np.int64(1), np.int64(9), np.int64(1), np.int64(6), np.int64(5), np.int64(7), np.int64(10), np.int64(3), np.int64(0), np.int64(9), np.int64(6), np.int64(2), np.int64(5), np.int64(1), np.int64(5), np.int64(1), np.int64(3), np.int64(1), np.int64(6), np.int64(7), np.int64(5), np.int64(2), np.int64(4), np.int64(4), np.int64(10), np.int64(6), np.int64(9), np.int64(7), np.int64(10), np.int64(8), np.int64(10), np.int64(7), np.int64(10), np.int64(4), np.int64(5), np.int64(1), np.int64(4), np.int64(3), np.int64(3), np.int64(1), np.int64(9), np.int64(1), np.int64(2), np.int64(7), np.int64(0), np.int64(10), np.int64(4), np.int64(0), np.int64(10), np.int64(9), np.int64(2), np.int64(8), np.int64(10), np.int64(3), np.int64(7), np.int64(9), np.int64(7), np.int64(4), np.int64(3), np.int64(1), np.int64(8), np.int64(0), np.int64(5), np.int64(4), np.int64(1), np.int64(10), np.int64(8), np.int64(5), np.int64(10), np.int64(4), np.int64(3), np.int64(6), np.int64(1), np.int64(6), np.int64(7), np.int64(5), np.int64(10), np.int64(4), np.int64(9), np.int64(8), np.int64(9), np.int64(0), np.int64(9), np.int64(5), np.int64(6), np.int64(8), np.int64(7), np.int64(5), np.int64(6), np.int64(5), np.int64(4), np.int64(1), np.int64(3), np.int64(9), np.int64(8), np.int64(1), np.int64(3), np.int64(3), np.int64(9), np.int64(4), np.int64(1), np.int64(5), np.int64(9), np.int64(1), np. ...
# all_predictions: [np.int64(10), np.int64(2), np.int64(9), np.int64(4), np.int64(5), np.int64(2), np.int64(6), np.int64(9), np.int64(2), np.int64(2), np.int64(7), np.int64(9), np.int64(5), np.int64(7), np.int64(3), np.int64(8), np.int64(6), np.int64(7), np.int64(2), np.int64(10), np.int64(4), np.int64(2), np.int64(2), np.int64(8), np.int64(3), np.int64(3), np.int64(1), np.int64(7), np.int64(2), np.int64(8), np.int64(2), np.int64(10), np.int64(8), np.int64(3), np.int64(0), np.int64(2), np.int64(6), np.int64(3), np.int64(4), np.int64(5), np.int64(1), np.int64(10), np.int64(10), np.int64(8), np.int64(3), np.int64(4), np.int64(9), np.int64(4), np.int64(10), np.int64(9), np.int64(7), np.int64(10), np.int64(1), np.int64(1), np.int64(4), np.int64(4), np.int64(7), np.int64(6), np.int64(0), np.int64(5), np.int64(5), np.int64(0), np.int64(7), np.int64(1), np.int64(2), np.int64(5), np.int64(4), np.int64(0), np.int64(6), np.int64(0), np.int64(4), np.int64(7), np.int64(10), np.int64(3), np.int64(3), np.int64(2), np.int64(2), np.int64(9), np.int64(5), np.int64(1), np.int64(9), np.int64(3), np.int64(9), np.int64(7), np.int64(6), np.int64(1), np.int64(5), np.int64(0), np.int64(0), np.int64(0), np.int64(9), np.int64(3), np.int64(4), np.int64(1), np.int64(8), np.int64(5), np.int64(5), np.int64(0), np.int64(7), np.int64(10), np.int64(5), np.int64(3), np.int64(2), np.int64(1), np.int64(8), np.int64(8), np.int64(7), np.int64(0), np.int64(10), np.int64(5), np.int64(8), np.int64(7), np.int64(9), np.int64(1), np.int64(10), np.int64(1), np.int64(7), np.int64(10), np.int64(3), np.int64(5), np.int64(3), np.int64(2), np.int64(8), np.int64(2), np.int64(5), np.int64(6), np.int64(6), np.int64(10), np.int64(6), np.int64(3), np.int64(0), np.int64(3), np.int64(8), np.int64(1), np.int64(4), np.int64(10), np.int64(3), np.int64(5), np.int64(1), np.int64(8), np.int64(1), np.int64(8), np.int64(7), np.int64(5), np.int64(0), np.int64(2), np.int64(3), np.int64(7), np.int64(10), np.int64(8), np.int64(0), np.int64(3), np.int64(0), np.int64(1), np.int64(10), np.int64(5), np.int64(1), np.int64(0), np.int64(6), np.int64(3), np.int64(1), np.int64(9), np.int64(5), np.int64(3), np.int64(1), np.int64(5), np.int64(4), np.int64(4), np.int64(10), np.int64(10), np.int64(10), np.int64(2), np.int64(7), np.int64(0), np.int64(2), np.int64(3), np.int64(9), np.int64(6), np.int64(2), np.int64(5), np.int64(2), np.int64(4), np.int64(0), np.int64(7), np.int64(10), np.int64(3), np.int64(10), np.int64(0), np.int64(0), np.int64(7), np.int64(2), np.int64(1), np.int64(8), np.int64(0), np.int64(4), np.int64(0), np.int64(0), np.int64(8), np.int64(2), np.int64(1), np.int64(1), np.int64(9), np.int64(1), np.int64(6), np.int64(5), np.int64(7), np.int64(10), np.int64(3), np.int64(0), np.int64(9), np.int64(6), np.int64(5), np.int64(5), np.int64(1), np.int64(5), np.int64(1), np.int64(3), np.int64(1), np.int64(6), np.int64(7), np.int64(5), np.int64(10), np.int64(4), np.int64(4), np.int64(10), np.int64(0), np.int64(9), np.int64(7), np.int64(10), np.int64(8), np.int64(10), np.int64(7), np.int64(10), np.int64(4), np.int64(3), np.int64(1), np.int64(4), np.int64(3), np.int64(3), np.int64(1), np.int64(5), np.int64(1), np.int64(2), np.int64(8), np.int64(0), np.int64(10), np.int64(4), np.int64(0), np.int64(10), np.int64(9), np.int64(7), np.int64(8), np.int64(10), np.int64(3), np.int64(7), np.int64(9), np.int64(7), np.int64(4), np.int64(3), np.int64(1), np.int64(8), np.int64(0), np.int64(5), np.int64(4), np.int64(1), np.int64(10), np.int64(8), np.int64(5), np.int64(10), np.int64(4), np.int64(3), np.int64(6), np.int64(1), np.int64(5), np.int64(4), np.int64(1), np.int64(10), np.int64(6), np.int64(9), np.int64(8), np.int64(0), np.int64(0), np.int64(5), np.int64(5), np.int64(9), np.int64(8), np.int64(1), np.int64(5), np.int64(6), np.int64(2), np.int64(4), np.int64(1), np.int64(3), np.int64(9), np.int64(8), np.int64(1), np.int64(3), np.int64(3), np.int64(9), np.int64(4), np.int64(1), np.int64(5), np.int64(9), np.int64(1 ...

# %%
cat_to_name_list = [cat_to_name[str(i)] for i in range(1, 12)]

cm = confusion_matrix(all_labels, all_predictions)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=cat_to_name_list)
disp.plot(cmap=plt.cm.Blues)
plt.xticks(rotation=90)
plt.show()

# %%
testing_img = Image.open("C:/Users/User/Downloads/ant.jpg")
transform = transforms.Compose([transforms.Resize((image_size, image_size)), transforms.ToTensor()])
testing_img = transform(testing_img).unsqueeze(0).cuda()
pred = restnet_model(testing_img)

probabilities = F.softmax(pred, dim=1)
predicted_class = torch.argmax(probabilities, dim=1).item()
predicted_label = cat_to_name[str(predicted_class + 1)]
print(f"Predicted class: {predicted_class}, Label: {predicted_label}")
# Out:
# Predicted class: 7, Label: Ladybug
